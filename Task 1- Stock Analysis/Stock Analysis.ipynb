# %%
import pandas as pd

# %%
dataset = pd.read_csv("2YearIBMStockData.csv")

# %%
dataset.plot()
# Out:
# <AxesSubplot:>

# %%
dataset.head()
# Out:
#               time     open    high      low   close  volume
# 0  3/25/2022 19:19  131.300  131.30  131.300  131.30     718
# 1  3/25/2022 19:18  131.300  131.30  131.300  131.30     282
# 2  3/25/2022 17:50  131.300  131.30  131.300  131.30     100
# 3  3/25/2022 16:59  131.340  131.35  131.340  131.35    1427
# 4  3/25/2022 16:42  131.326  131.35  131.326  131.35    1326

# %%
dataset.tail()
# Out:
#                  time       open       high        low      close  volume
# 216878  4/6/2020 7:27  95.385037  95.385037  95.385037  95.385037     854
# 216879  4/6/2020 7:25  94.530379  94.530379  94.530379  94.530379     450
# 216880  4/6/2020 7:08  94.703037  94.703037  94.703037  94.703037     436
# 216881  4/6/2020 7:02  95.479999  95.479999  95.479999  95.479999     575
# 216882  4/6/2020 7:01  94.979290  94.979290  94.979290  94.979290     452

# %%
dataset.describe()
# Out:
#                 open           high            low          close  \
# count  216883.000000  216883.000000  216883.000000  216883.000000
# mean      118.568888     118.610088     118.527167     118.568678
# std        11.032437      11.030216      11.034414      11.032587
# min        93.893379      94.001154      93.878046      93.894886
# 25%       109.270433     109.306157     109.232227     109.272002
# 50%       116.919510     116.953384     116.880199     116.919510
# 75%       129.697796     129.731458     129.666234     129.700000
# max       140.686324     140.778433     140.363945     140.658692
#
#              volume
# count  2.168830e+05
# mean   1.123028e+04
# std    2.550945e+04
# min    0.000000e+00
# 25%    3.895500e+03
# 50%    6.786000e+03
# 75%    1.175100e+04
# max    2.110106e+06

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216883 entries, 0 to 216882
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   time    216883 non-null  object
#  1   open    216883 non-null  float64
#  2   high    216883 non-null  float64
#  3   low     216883 non-null  float64
#  4   close   216883 non-null  float64
#  5   volume  216883 non-null  int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 9.9+ MB

# %%
dataset.dropna()
# Out:
#                    time        open        high         low       close  \
# 0       3/25/2022 19:19  131.300000  131.300000  131.300000  131.300000
# 1       3/25/2022 19:18  131.300000  131.300000  131.300000  131.300000
# 2       3/25/2022 17:50  131.300000  131.300000  131.300000  131.300000
# 3       3/25/2022 16:59  131.340000  131.350000  131.340000  131.350000
# 4       3/25/2022 16:42  131.326000  131.350000  131.326000  131.350000
# ...                 ...         ...         ...         ...         ...
# 216878    4/6/2020 7:27   95.385037   95.385037   95.385037   95.385037
# 216879    4/6/2020 7:25   94.530379   94.530379   94.530379   94.530379
# 216880    4/6/2020 7:08   94.703037   94.703037   94.703037   94.703037
# 216881    4/6/2020 7:02   95.479999   95.479999   95.479999   95.479999
# 216882    4/6/2020 7:01   94.979290   94.979290   94.979290   94.979290
#
#         volume
# 0          718
# 1          282
# 2          100
# 3         1427
# 4         1326
# ...

# %%
dataset.isnull()
# Out:
#          time   open   high    low  close  volume
# 0       False  False  False  False  False   False
# 1       False  False  False  False  False   False
# 2       False  False  False  False  False   False
# 3       False  False  False  False  False   False
# 4       False  False  False  False  False   False
# ...       ...    ...    ...    ...    ...     ...
# 216878  False  False  False  False  False   False
# 216879  False  False  False  False  False   False
# 216880  False  False  False  False  False   False
# 216881  False  False  False  False  False   False
# 216882  False  False  False  False  False   False
#
# [216883 rows x 6 columns]

# %%
dataset.isnull().sum()
# Out:
# time      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
dataset.rank()
# Out:
#             time      open      high       low     close   volume
# 0       103235.0  177561.5  177206.0  177886.0  177549.0  14743.0
# 1       103234.0  177561.5  177206.0  177886.0  177549.0   7995.0
# 2       103233.0  177561.5  177206.0  177886.0  177549.0    144.5
# 3       103232.0  177890.5  177599.5  178261.0  177970.0  19647.0
# 4       103231.0  177750.0  177599.5  178109.0  177970.0  18975.5
# ...          ...       ...       ...       ...       ...      ...
# 216878  123696.0     512.0     488.5     535.0     512.0  15775.5
# 216879  123695.0     150.5     129.5     177.5     156.5  11439.0
# 216880  123694.0     258.0     232.0     287.0     266.0  11228.5
# 216881  123693.0     548.0     525.0     563.0     547.0  13444.5
# 216882  123692.0     377.5     369.5     390.5     382.5  11473.5
#
# [216883 rows x 6 columns]

# %%
dataset.count()
# Out:
# time      216883
# open      216883
# high      216883
# low       216883
# close     216883
# volume    216883
# dtype: int64

# %%
dataset.min()
# Out:
# time      1/10/2022 10:00
# open            93.893379
# high            94.001154
# low             93.878046
# close           93.894886
# volume                  0
# dtype: object

# %%
dataset.max()
# Out:
# time      9/9/2021 9:59
# open         140.686324
# high         140.778433
# low          140.363945
# close        140.658692
# volume          2110106
# dtype: object
